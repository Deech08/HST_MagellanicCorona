# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

import astropy.units as u

# %%
def M200(T):
    return 1537.7*T**(3/2)

# %%
T = np.logspace(4,6.5,1000)

# %%
fig,ax = plt.subplots()

ax.plot(np.log10(T), np.log10(M200(T)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
np.log10((3e12 * u.cm**-2 / (.05*u.kpc)).to(u.cm**-3).value)
# Out:
# -7.711199294838495
